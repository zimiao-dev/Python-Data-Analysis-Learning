# %% [markdown]
# # matplotlib learning

# %% [markdown]
# - 折线图 plot
# - 条形图 bar
# - 饼图 pie
# - 散点图 scatter
# - 箱线图 boxplot
# - 多个图表
# - 组合图

# %% [markdown]
# ## 01 折线图

# %%
import matplotlib.pyplot as plt

# %%
# 创建图表，设置大小
plt.figure(figsize=(10, 5))

# %%
# 显示图表
plt.show()
