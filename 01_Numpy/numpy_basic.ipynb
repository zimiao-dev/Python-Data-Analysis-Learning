# %% [markdown]
# # ndarray
# ## ndarray 的特性
# ### 多维性

# %%
import numpy as np
from numpy.f2py.crackfortran import dimensionpattern

# %%
arr = np.array(5)
print(arr)
print('arr的维度: ', arr.ndim) # number of dimensions
# Out:
# 5
# arr的维度:  0
