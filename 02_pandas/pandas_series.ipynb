# %% [markdown]
# # series
# ## 01 series 的创建

# %%
import pandas as pd

# %%
# series 的创建
s = pd.Series([1, 2, 3, 4, 5])
print(s)
# 自定义索引
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
